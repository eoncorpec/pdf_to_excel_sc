# %%
import pandas as pd
import numpy as np
import tabula
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_10512\3008533230.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
pdf = "../Inputs/Doc1/DocEconomica_731956_3_1_1_2020_11_04_19_44_42_860.pdf"

# %%
first = tabula.read_pdf(pdf, pages=1, area=(100,19,816,577), lattice=True, output_format="dataframe", encoding="latin-1")
second = tabula.read_pdf(pdf, pages=2, area=(20,19,823,575), lattice=True, output_format="dataframe", encoding="latin-1")
third = tabula.read_pdf(pdf, pages=3, area=(20,19,823,575), lattice=True, output_format="dataframe", encoding="latin-1")
fourth = tabula.read_pdf(pdf, pages=4, area=(20,19,823,575), lattice=True, output_format="dataframe", encoding="latin-1")
fifth = tabula.read_pdf(pdf, pages=5, area=(20,19,823,575), lattice=True, output_format="dataframe", encoding="latin-1")
sixth = tabula.read_pdf(pdf, pages=6, area=(20,19,823,575), lattice=True, output_format="dataframe", encoding="latin-1")
seventh = tabula.read_pdf(pdf, pages=7, area=(20,19,275,576), lattice=True, output_format="dataframe", encoding="latin-1")
Header = tabula.read_pdf(pdf, pages=1, area=(20,20,112,576), lattice=True, output_format="dataframe", encoding="latin-1")
# Out:
# Error importing jpype dependencies. Fallback to subprocess.
# No module named 'jpype'

# %%
daf1 = first[0]
daf2 = second[0]
daf3 = third[0]
daf4 = fourth[0]
daf5 = fifth[0]
daf6 = sixth[0]
daf7 = seventh[0]
dafHeader = Header[0]

# %%
daf1
# Out:
#                      Unnamed: 0  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6                           NaN
# 7                           NaN
# 8                           NaN
# 9                           NaN
# 10                          NaN
# 11                          NaN
# 12                          NaN
# 13                          NaN
# 14                          NaN
# 15                          NaN
# 16                          NaN
# 17                          NaN
# 18                          NaN
# 19                          NaN
# 20                          NaN
# 21                          NaN
# 22                          NaN
# 23                          NaN
# 24                          NaN
# 25                          NaN
# 26                          NaN
# 27                          NaN
# ...

# %%
print(daf1.index[49]) # o con -1
daf1.fillna("d", inplace=True)
daf1.rename(inplace=True, columns={"null": "CODS"})

daf1.drop(["Unnamed: 0"], axis=1, inplace=True)
daf1.iloc[daf1.index[-1]] = {"FECHA DE LA JUNTA QUE APROBÓ LOS ESTADOS FINANCIEROS (DD/MM/AAA)":"CUOTAS DE FONDOS COLECTIVOS",
                            "CODS":"10102020102", "Unnamed: 3":"0.00"}

daf1.rename(inplace=True, columns={"FECHA DE LA JUNTA QUE APROBÓ LOS ESTADOS FINANCIEROS (DD/MM/AAA)":"CUENTA", 
                                "CODS":"CODS1",  "Unnamed: 3":"VALOR EN USD"})
daf1.drop("CODS1", axis=1, inplace=True)
daf1.drop([0,1], inplace=True)
daf1.head(10)
# Out:
# 49
#                                                CUENTA VALOR EN USD
# 2                                              ACTIVO       100.00
# 3                                    ACTIVO CORRIENTE       100.00
# 4                 EFECTIVO Y EQUIVALENTES DE EFECTIVO       100.00
# 5                                                CAJA         0.00
# 6                  INSTITUCIONES FINANCIERAS PÚBLICAS         0.00
# 7                  INSTITUCIONES FINANCIERAS PRIVADAS       100.00
# 8                                 ACTIVOS FINANCIEROS         0.00
# 9   ACTIVOS FINANCIEROS A VALOR RAZONABLE CON CAMB...         0.00
# 10                                     RENTA VARIABLE         0.00
# 11                         ACCIONES Y PARTICIPACIONES         0.00

# %%
daf1
# Out:
#                                                CUENTA VALOR EN USD
# 2                                              ACTIVO       100.00
# 3                                    ACTIVO CORRIENTE       100.00
# 4                 EFECTIVO Y EQUIVALENTES DE EFECTIVO       100.00
# 5                                                CAJA         0.00
# 6                  INSTITUCIONES FINANCIERAS PÚBLICAS         0.00
# 7                  INSTITUCIONES FINANCIERAS PRIVADAS       100.00
# 8                                 ACTIVOS FINANCIEROS         0.00
# 9   ACTIVOS FINANCIEROS A VALOR RAZONABLE CON CAMB...         0.00
# 10                                     RENTA VARIABLE         0.00
# 11                         ACCIONES Y PARTICIPACIONES         0.00
# 12                        CUOTAS DE FONDOS COLECTIVOS         0.00
# 13        VALORES DE  TITULARIZACIÓN DE PARTICIPACIÓN         0.00
# 14                          UNIDADES DE PARTICIPACIÓN         0.00
# ...

# %%
daf2
# Out:
#     Unnamed: 0                     ESTADO DE SITUACIÓN FINANCIERA  \
# 0          NaN                                             CUENTA
# 1          NaN                          UNIDADES DE PARTICIPACIÓN
# 2          NaN        VALORES DE  TITULARIZACIÓN DE PARTICIPACIÓN
# 3          NaN                         INVERSIONES EN EL EXTERIOR
# 4          NaN                                              OTROS
# 5          NaN                                         RENTA FIJA
# 6          NaN                                             AVALES
# 7          NaN                                   BONOS DEL ESTADO
# 8          NaN                                    BONOS DE PRENDA
# 9          NaN                               CÉDULAS HIPOTECARIAS
# 10         NaN                           CERTIFICADOS FINANCIEROS
# 11         NaN                          CERTIFICADOS DE INVERSIÓN
# 12         NaN                          CERTIFICADOS DE TESORERÍA
# ...

# %%
daf2.drop(["Unnamed: 0","Unnamed: 2"], axis=1, inplace=True)
daf2.drop([0], inplace=True)
daf2.rename(inplace=True, columns={"ESTADO DE SITUACIÓN FINANCIERA":"CUENTA",  "Unnamed: 3":"VALOR EN USD"})
daf2.head(10)
# Out:
#                                          CUENTA VALOR EN USD
# 1                     UNIDADES DE PARTICIPACIÓN         0.00
# 2   VALORES DE  TITULARIZACIÓN DE PARTICIPACIÓN         0.00
# 3                    INVERSIONES EN EL EXTERIOR         0.00
# 4                                         OTROS         0.00
# 5                                    RENTA FIJA         0.00
# 6                                        AVALES         0.00
# 7                              BONOS DEL ESTADO         0.00
# 8                               BONOS DE PRENDA         0.00
# 9                          CÉDULAS HIPOTECARIAS         0.00
# 10                     CERTIFICADOS FINANCIEROS         0.00

# %%
daf3
# Out:
#     Unnamed: 0                     ESTADO DE SITUACIÓN FINANCIERA  \
# 0          NaN                                             CUENTA
# 1          NaN                             PÓLIZAS DE ACUMULACIÓN
# 2          NaN                          TÍTULOS DEL BANCO CENTRAL
# 3          NaN                          VALORES DE TITULARIZACIÓN
# 4          NaN                         INVERSIONES EN EL EXTERIOR
# 5          NaN                                              OTROS
# 6          NaN     PROVISIÓN POR DETERIORO DE ACTIVOS FINANCIEROS
# 7          NaN  ACTIVOS FINANCIEROS A VALOR RAZONABLE CON CAMB...
# 8          NaN      ACTIVOS FINANCIEROS DISPONIBLES PARA LA VENTA
# 9          NaN  ACTIVOS FINANCIEROS MANTENIDOS HASTA EL VENCIM...
# 10         NaN    DOCUMENTOS Y CUENTAS POR COBRAR NO RELACIONADOS
# 11         NaN    DE ACTIVIDADES ORDINARIAS QUE GENEREN INTERESES
# 12         NaN          CUENTAS Y DOCUMENTOS A COBRAR  A CLIENTES
# ...

# %%
daf3.drop(["Unnamed: 0", "Unnamed: 2"], axis=1, inplace=True)
daf3.drop([0], inplace=True)
daf3.rename(inplace=True, columns={"ESTADO DE SITUACIÓN FINANCIERA":"CUENTA",  "Unnamed: 3":"VALOR EN USD"})
daf3.head(10)
# Out:
#                                                CUENTA VALOR EN USD
# 1                              PÓLIZAS DE ACUMULACIÓN         0.00
# 2                           TÍTULOS DEL BANCO CENTRAL         0.00
# 3                           VALORES DE TITULARIZACIÓN         0.00
# 4                          INVERSIONES EN EL EXTERIOR         0.00
# 5                                               OTROS         0.00
# 6      PROVISIÓN POR DETERIORO DE ACTIVOS FINANCIEROS         0.00
# 7   ACTIVOS FINANCIEROS A VALOR RAZONABLE CON CAMB...         0.00
# 8       ACTIVOS FINANCIEROS DISPONIBLES PARA LA VENTA         0.00
# 9   ACTIVOS FINANCIEROS MANTENIDOS HASTA EL VENCIM...         0.00
# 10    DOCUMENTOS Y CUENTAS POR COBRAR NO RELACIONADOS         0.00

# %%
daf4
# Out:
#     Unnamed: 0                     ESTADO DE SITUACIÓN FINANCIERA Unnamed: 2  \
# 0          NaN                                             CUENTA     CÓDIGO
# 1          NaN                SERVICIOS Y OTROS PAGOS ANTICIPADOS      10104
# 2          NaN                     SEGUROS PAGADOS POR ANTICIPADO    1010401
# 3          NaN                   ARRIENDOS PAGADOS POR ANTICIPADO    1010402
# 4          NaN                            ANTICIPOS A PROVEEDORES    1010403
# 5          NaN                         OTROS ANTICIPOS ENTREGADOS    1010404
# 6          NaN                   ACTIVOS POR IMPUESTOS CORRIENTES      10105
# 7          NaN     CRÉDITO TRIBUTARIO A FAVOR DE LA EMPRESA (IVA)    1010501
# 8          NaN  CRÉDITO TRIBUTARIO A FAVOR DE LA EMPRESA ( I. R.)    1010502
# 9          NaN                    ANTICIPO DE IMPUESTO A LA RENTA    1010503
# 10         NaN  ACTIVOS CORRIENTES MANTENIDOS PARA LA VENTA Y ...      10106
# ...

# %%
daf4.drop(["Unnamed: 0", "Unnamed: 2"], axis=1, inplace=True)
daf4.drop([0], inplace=True)
daf4.rename(inplace=True, columns={"ESTADO DE SITUACIÓN FINANCIERA":"CUENTA",  "Unnamed: 3":"VALOR EN USD"})
daf4.head(10)
# Out:
#                                                CUENTA VALOR EN USD
# 1                 SERVICIOS Y OTROS PAGOS ANTICIPADOS         0.00
# 2                      SEGUROS PAGADOS POR ANTICIPADO         0.00
# 3                    ARRIENDOS PAGADOS POR ANTICIPADO         0.00
# 4                             ANTICIPOS A PROVEEDORES         0.00
# 5                          OTROS ANTICIPOS ENTREGADOS         0.00
# 6                    ACTIVOS POR IMPUESTOS CORRIENTES         0.00
# 7      CRÉDITO TRIBUTARIO A FAVOR DE LA EMPRESA (IVA)         0.00
# 8   CRÉDITO TRIBUTARIO A FAVOR DE LA EMPRESA ( I. R.)         0.00
# 9                     ANTICIPO DE IMPUESTO A LA RENTA         0.00
# 10  ACTIVOS CORRIENTES MANTENIDOS PARA LA VENTA Y ...         0.00

# %%
daf5
# Out:
#     Unnamed: 0                     ESTADO DE SITUACIÓN FINANCIERA Unnamed: 2  \
# 0          NaN                                             CUENTA     CÓDIGO
# 1          NaN                    DOCUMENTOS Y CUENTAS POR COBRAR    1020603
# 2          NaN  (-) PROVISIÓN CUENTAS INCOBRABLES DE ACTIVOS F...    1020604
# 3          NaN     ACTIVOS ADQUIRIDOS EN ARRENDAMIENTO FINANCIERO      10207
# 4          NaN                        OTROS ACTIVOS NO CORRIENTES      10208
# 5          NaN                               DERECHOS FIDUCIARIOS    1020801
# 6          NaN                              DEPÓSITOS EN GARANTÍA    1020802
# 7          NaN   DEPÓSITOS EN GARANTÍA POR OPERACIONES BURSÁTILES    1020803
# 8          NaN                 CUOTA PATRIMONIAL BOLSA DE VALORES    1020804
# 9          NaN          ACCIONES DEPÒSITO CENTRALIZADO DE VALORES    1020805
# 10         NaN                           INVERSIONES SUBSIDIARIAS    1020806
# ...

# %%
daf5.drop(["Unnamed: 0", "Unnamed: 2"], axis=1, inplace=True)
daf5.drop([0], inplace=True)
daf5.rename(inplace=True, columns={"ESTADO DE SITUACIÓN FINANCIERA":"CUENTA",  "Unnamed: 3":"VALOR EN USD"})
daf5.head(10)
# Out:
#                                                CUENTA VALOR EN USD
# 1                     DOCUMENTOS Y CUENTAS POR COBRAR         0.00
# 2   (-) PROVISIÓN CUENTAS INCOBRABLES DE ACTIVOS F...         0.00
# 3      ACTIVOS ADQUIRIDOS EN ARRENDAMIENTO FINANCIERO         0.00
# 4                         OTROS ACTIVOS NO CORRIENTES         0.00
# 5                                DERECHOS FIDUCIARIOS         0.00
# 6                               DEPÓSITOS EN GARANTÍA         0.00
# 7    DEPÓSITOS EN GARANTÍA POR OPERACIONES BURSÁTILES         0.00
# 8                  CUOTA PATRIMONIAL BOLSA DE VALORES         0.00
# 9           ACCIONES DEPÒSITO CENTRALIZADO DE VALORES         0.00
# 10                           INVERSIONES SUBSIDIARIAS         0.00

# %%
daf6
# Out:
#     Unnamed: 0                     ESTADO DE SITUACIÓN FINANCIERA Unnamed: 2  \
# 0          NaN                                             CUENTA     CÓDIGO
# 1          NaN                                       POR CUSTODIA    2011303
# 2          NaN                                 POR ADMINISTRACIÓN    2011304
# 3          NaN                                   OTRAS COMISIONES    2011305
# 4          NaN                                 SANCIONES Y MULTAS    2011306
# 5          NaN                                    INDEMNIZACIONES    2011307
# 6          NaN                            OBLIGACIONES JUDICIALES    2011308
# 7          NaN                      ACREEDORES POR INTERMEDIACIÓN    2011309
# 8          NaN              OBLIGACIÓN POR COMPROMISO DE RECOMPRA    2011310
# 9          NaN                      POR CONTRATOS DE UNDERWRITING    2011311
# 10         NaN                                              OTROS    2011312
# ...

# %%
daf6.drop(["Unnamed: 0", "Unnamed: 2"], axis=1, inplace=True)
daf6.drop([0], inplace=True)
daf6.rename(inplace=True, columns={"ESTADO DE SITUACIÓN FINANCIERA":"CUENTA",  "Unnamed: 3":"VALOR EN USD"})
daf6.head(10)
# Out:
#                                    CUENTA VALOR EN USD
# 1                            POR CUSTODIA         0.00
# 2                      POR ADMINISTRACIÓN         0.00
# 3                        OTRAS COMISIONES         0.00
# 4                      SANCIONES Y MULTAS         0.00
# 5                         INDEMNIZACIONES         0.00
# 6                 OBLIGACIONES JUDICIALES         0.00
# 7           ACREEDORES POR INTERMEDIACIÓN         0.00
# 8   OBLIGACIÓN POR COMPROMISO DE RECOMPRA         0.00
# 9           POR CONTRATOS DE UNDERWRITING         0.00
# 10                                  OTROS         0.00

# %%
daf7
# Out:
#                     Unnamed: 0  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9                          NaN
# 10                         NaN
# 11                         NaN
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16  PARTICIPACIÓN CONTROLADORA
#
#                        ESTADO DE SITUACIÓN FINANCIERA Unnamed: 2  \
# 0                                              CUENTA     CÓDIGO
# 1   SUPERAVIT DE ACTIVOS FINANCIEROS DISPONIBLES P...      30501
# 2   SUPERAVIT POR REVALUACIÓN DE PROPIEDADES, PLAN...      30502
# 3    SUPERAVIT POR REVALUACION DE ACTIVOS INTANGIBLES      30503
# ...

# %%
print(daf7.iloc[-1])
# Out:
# Unnamed: 0                        PARTICIPACIÓN CONTROLADORA
# ESTADO DE SITUACIÓN FINANCIERA                            31
# Unnamed: 2                                               NaN
# Unnamed: 3                                               NaN
# Unnamed: 4                                               NaN
# Name: 16, dtype: object

# %%
daf7.drop(["Unnamed: 0","Unnamed: 2","Unnamed: 4"], axis=1, inplace=True)
daf7.drop([0], inplace=True)
daf7.iloc[daf7.index[-1]] = {"ESTADO DE SITUACIÓN FINANCIERA":"PARTICIPACIÓN CONTROLADORA",
                            "Unnamed: 3":"0.00"}
daf7.rename(inplace=True, columns={"ESTADO DE SITUACIÓN FINANCIERA":"CUENTA",  "Unnamed: 3":"VALOR EN USD"})
daf7
# Out:
#                                                CUENTA VALOR EN USD
# 1   SUPERAVIT DE ACTIVOS FINANCIEROS DISPONIBLES P...         0.00
# 2   SUPERAVIT POR REVALUACIÓN DE PROPIEDADES, PLAN...         0.00
# 3    SUPERAVIT POR REVALUACION DE ACTIVOS INTANGIBLES         0.00
# 4                     OTROS SUPERAVIT POR REVALUACION         0.00
# 5                               RESULTADOS ACUMULADOS         0.00
# 6                                GANANCIAS ACUMULADAS         0.00
# 7                             (-) PÉRDIDAS ACUMULADAS         0.00
# 8   RESULTADOS ACUMULADOS PROVENIENTES DE LA ADOPC...         0.00
# 9                                  RESERVA DE CAPITAL         0.00
# 10                             RESERVA POR DONACIONES         0.00
# 11                              RESERVA POR VALUACIÓN         0.00
# 12           SUPERÁVIT POR REVALUACIÓN DE INVERSIONES         0.00
# 13                           RESULTADOS DEL EJERCICIO         0.00
# ...

# %%
daf7
# Out:
#                                                CUENTA VALOR EN USD
# 1   SUPERAVIT DE ACTIVOS FINANCIEROS DISPONIBLES P...         0.00
# 2   SUPERAVIT POR REVALUACIÓN DE PROPIEDADES, PLAN...         0.00
# 3    SUPERAVIT POR REVALUACION DE ACTIVOS INTANGIBLES         0.00
# 4                     OTROS SUPERAVIT POR REVALUACION         0.00
# 5                               RESULTADOS ACUMULADOS         0.00
# 6                                GANANCIAS ACUMULADAS         0.00
# 7                             (-) PÉRDIDAS ACUMULADAS         0.00
# 8   RESULTADOS ACUMULADOS PROVENIENTES DE LA ADOPC...         0.00
# 9                                  RESERVA DE CAPITAL         0.00
# 10                             RESERVA POR DONACIONES         0.00
# 11                              RESERVA POR VALUACIÓN         0.00
# 12           SUPERÁVIT POR REVALUACIÓN DE INVERSIONES         0.00
# 13                           RESULTADOS DEL EJERCICIO         0.00
# ...

# %%
daf7.drop([16], inplace=True)
#daf7.iloc[daf7.index[15]] = {"CUENTA":"PARTICIPACIÓN CONTROLADORA", "VALOR EN USD":"0.00"}
#daf7

# %%
daf7
# Out:
#                                                CUENTA VALOR EN USD
# 1   SUPERAVIT DE ACTIVOS FINANCIEROS DISPONIBLES P...         0.00
# 2   SUPERAVIT POR REVALUACIÓN DE PROPIEDADES, PLAN...         0.00
# 3    SUPERAVIT POR REVALUACION DE ACTIVOS INTANGIBLES         0.00
# 4                     OTROS SUPERAVIT POR REVALUACION         0.00
# 5                               RESULTADOS ACUMULADOS         0.00
# 6                                GANANCIAS ACUMULADAS         0.00
# 7                             (-) PÉRDIDAS ACUMULADAS         0.00
# 8   RESULTADOS ACUMULADOS PROVENIENTES DE LA ADOPC...         0.00
# 9                                  RESERVA DE CAPITAL         0.00
# 10                             RESERVA POR DONACIONES         0.00
# 11                              RESERVA POR VALUACIÓN         0.00
# 12           SUPERÁVIT POR REVALUACIÓN DE INVERSIONES         0.00
# 13                           RESULTADOS DEL EJERCICIO         0.00
# ...

# %%
nueva_fila = {"CUENTA": "PARTICIPACIÓN CONTROLADORA", "VALOR EN USD": "0.00"}
daf7 = daf7._append(nueva_fila, ignore_index=True)

# %%
daf7
# Out:
#                                                CUENTA VALOR EN USD
# 0   SUPERAVIT DE ACTIVOS FINANCIEROS DISPONIBLES P...         0.00
# 1   SUPERAVIT POR REVALUACIÓN DE PROPIEDADES, PLAN...         0.00
# 2    SUPERAVIT POR REVALUACION DE ACTIVOS INTANGIBLES         0.00
# 3                     OTROS SUPERAVIT POR REVALUACION         0.00
# 4                               RESULTADOS ACUMULADOS         0.00
# 5                                GANANCIAS ACUMULADAS         0.00
# 6                             (-) PÉRDIDAS ACUMULADAS         0.00
# 7   RESULTADOS ACUMULADOS PROVENIENTES DE LA ADOPC...         0.00
# 8                                  RESERVA DE CAPITAL         0.00
# 9                              RESERVA POR DONACIONES         0.00
# 10                              RESERVA POR VALUACIÓN         0.00
# 11           SUPERÁVIT POR REVALUACIÓN DE INVERSIONES         0.00
# 12                           RESULTADOS DEL EJERCICIO         0.00
# ...

# %%
dafHeader
# Out:
#                                           Unnamed: 0  \
# 0                                          DIRECCIÓN
# 1                                         EXPEDIENTE
# 2                                                RUC
# 3                                                AÑO
# 4                                         FORMULARIO
# 5  FECHA DE LA JUNTA QUE APROBÓ LOS ESTADOS FINAN...
#
#                             RAZÓN SOCIAL  J2R TECH S.A.S.  Unnamed: 3
# 0  yanahurco Y rio upano No. s/n BARRIO:              NaN         NaN
# 1                                 731956              NaN         NaN
# 2                          0190493105001              NaN         NaN
# 3                                   2020              NaN         NaN
# 4                 SCV.NIIF.731956.2020.1              NaN         NaN
# 5                                    NaN              NaN         NaN

# %%
dafHeader.drop(["J2R TECH S.A.S.","Unnamed: 3"], axis=1, inplace=True)
dafHeader.rename(inplace=True, columns={"Unnamed: 0":"RAZÓN SOCIAL", "RAZÓN SOCIAL":"J2R TECH S.A.S."})
dafHeader
# Out:
#                                         RAZÓN SOCIAL  \
# 0                                          DIRECCIÓN
# 1                                         EXPEDIENTE
# 2                                                RUC
# 3                                                AÑO
# 4                                         FORMULARIO
# 5  FECHA DE LA JUNTA QUE APROBÓ LOS ESTADOS FINAN...
#
#                          J2R TECH S.A.S.
# 0  yanahurco Y rio upano No. s/n BARRIO:
# 1                                 731956
# 2                          0190493105001
# 3                                   2020
# 4                 SCV.NIIF.731956.2020.1
# 5                                    NaN

# %%
columns_names = ["REPRESENTANTE LEGAL","CONTADOR"]
pandas_options = {"names":columns_names}
contador = tabula.read_pdf(pdf, pages=7, area=(608,16,666,376), lattice=False, output_format="dataframe", encoding="latin-1", multiple_tables=True, pandas_options=pandas_options)
dafContador = contador[0]

# %%
dafContador.drop([0], inplace=True)
dafContador
# Out:
#             REPRESENTANTE LEGAL CONTADOR
# 1  SANCHEZ SALAZAR JOSE ANTONIO      NaN
# 2                    0705952547      NaN
# 3                           NaN      NaN

# %%
dafData = pd.concat([daf1,daf2, daf3, daf4, daf5, daf6, daf7])

# %%
dafData
# Out:
#                                       CUENTA VALOR EN USD
# 2                                     ACTIVO       100.00
# 3                           ACTIVO CORRIENTE       100.00
# 4        EFECTIVO Y EQUIVALENTES DE EFECTIVO       100.00
# 5                                       CAJA         0.00
# 6         INSTITUCIONES FINANCIERAS PÚBLICAS         0.00
# ..                                       ...          ...
# 11  SUPERÁVIT POR REVALUACIÓN DE INVERSIONES         0.00
# 12                  RESULTADOS DEL EJERCICIO         0.00
# 13                 GANANCIA NETA DEL PERIODO         0.00
# 14              (-) PÉRDIDA NETA DEL PERIODO         0.00
# 15                PARTICIPACIÓN CONTROLADORA         0.00
#
# [339 rows x 2 columns]

# %%
texto = dafData["CUENTA"].to_list()
valores_list = dafData["VALOR EN USD"].to_list()

# %%
valores = np.array(valores_list).reshape(1,-1)
dfDatos = pd.DataFrame(valores, columns=texto)

# %%
dfDatos
# Out:
#    ACTIVO ACTIVO CORRIENTE EFECTIVO Y EQUIVALENTES DE EFECTIVO  CAJA  \
# 0  100.00           100.00                              100.00  0.00
#
#   INSTITUCIONES FINANCIERAS PÚBLICAS INSTITUCIONES FINANCIERAS PRIVADAS  \
# 0                               0.00                             100.00
#
#   ACTIVOS FINANCIEROS  \
# 0                0.00
#
#   ACTIVOS FINANCIEROS A VALOR RAZONABLE CON CAMBIOS EN RESULTADOS  \
# 0                                               0.00
#
#   RENTA VARIABLE ACCIONES Y PARTICIPACIONES  ... (-) PÉRDIDAS ACUMULADAS  \
# 0           0.00                       0.00  ...                    0.00
#
#   RESULTADOS ACUMULADOS PROVENIENTES DE LA ADOPCION POR PRIMERA VEZ DE LAS NIIF  \
# 0                                               0.00
#
#   RESERVA DE CAPITAL RESERVA POR DONACIONES RESERVA POR VALUACIÓN  \
# 0               0.00                   0.00                  0.00
#
#   SUPERÁVIT POR REVALUACIÓN DE INVERSIONES RESULTADOS DEL EJERCICIO  \
# ...

# %%
with pd.ExcelWriter("../Outputs/Doc1/InfoEconomica731956.xlsx", engine="xlsxwriter") as writer:
    dafHeader.to_excel(writer, sheet_name="Encabezado", index=False)
    dafContador.to_excel(writer, sheet_name="Encabezado", index=False, startrow=len(dafHeader)+2)
    dfDatos.to_excel(writer, sheet_name="Datos", index=False)
