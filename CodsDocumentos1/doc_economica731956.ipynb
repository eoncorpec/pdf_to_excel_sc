# %%
import pandas as pd
import numpy as np
import tabula

# %%
pdf = "../Inputs/DocEconomica_384_3_1_1_2020_12_31_00_00_00_000.pdf"

# %%
first = tabula.read_pdf(pdf, pages=1, area=(100,19,816,577), lattice=True, output_format="dataframe", encoding="latin-1")
second = tabula.read_pdf(pdf, pages=2, area=(20,19,823,575), lattice=True, output_format="dataframe", encoding="latin-1")
third = tabula.read_pdf(pdf, pages=3, area=(20,19,823,575), lattice=True, output_format="dataframe", encoding="latin-1")
fourth = tabula.read_pdf(pdf, pages=4, area=(20,19,823,575), lattice=True, output_format="dataframe", encoding="latin-1")
fifth = tabula.read_pdf(pdf, pages=5, area=(20,19,823,575), lattice=True, output_format="dataframe", encoding="latin-1")
sixth = tabula.read_pdf(pdf, pages=6, area=(20,19,823,575), lattice=True, output_format="dataframe", encoding="latin-1")
seventh = tabula.read_pdf(pdf, pages=7, area=(20,19,275,576), lattice=True, output_format="dataframe", encoding="latin-1")
Header = tabula.read_pdf(pdf, pages=1, area=(20,20,112,576), lattice=True, output_format="dataframe", encoding="latin-1")
# Out:
# Error importing jpype dependencies. Fallback to subprocess.
# No module named 'jpype'

# %%
daf1 = first[0]
daf2 = second[0]
daf3 = third[0]
daf4 = fourth[0]
daf5 = fifth[0]
daf6 = sixth[0]
daf7 = seventh[0]
dafHeader = Header[0]

# %%
daf1
# Out:
#                      Unnamed: 0  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6                           NaN
# 7                           NaN
# 8                           NaN
# 9                           NaN
# 10                          NaN
# 11                          NaN
# 12                          NaN
# 13                          NaN
# 14                          NaN
# 15                          NaN
# 16                          NaN
# 17                          NaN
# 18                          NaN
# 19                          NaN
# 20                          NaN
# 21                          NaN
# 22                          NaN
# 23                          NaN
# 24                          NaN
# 25                          NaN
# 26                          NaN
# 27                          NaN
# 28                          NaN
# 29                          NaN
# 30                          NaN
# 31                          NaN
# 32                          NaN
# 33                          NaN
# 34                          NaN
# 35                          NaN
# 36                          NaN
# 37                          NaN
# 38                          NaN
# 39                          NaN
# 40                          NaN
# 41                          NaN
# 42                          NaN
# 43                          NaN
# 44                          NaN
# 45                          NaN
# 46                          NaN
# 47                          NaN
# 48                          NaN
# 49  CUOTAS DE FONDOS COLECTIVOS
#
#    FECHA DE LA JUNTA QUE APROBÃ LOS ESTADOS FINANCIEROS (DD/MM/AAA)  \
# 0                     ESTADO DE SITUACIÃN FINANCIERA
# 1                                              CUENTA
# 2                                              ACTIVO
# 3                                    ACTIVO CORRIENTE
# 4                 EFECTIVO Y EQUIVALENTES DE EFECTIVO
# 5                                                CAJA
# 6                 INSTITUCIONES FINANCIERAS PÃBLICAS
# 7                  INSTITUCIONES FINANCIERAS PRIVADAS
# 8                                 ACTIVOS FINANCIEROS
# 9   ACTIVOS FINANCIEROS A VALOR RAZONABLE CON CAMB...
# 10                                     RENTA VARIABLE
# 11                         ACCIONES Y PARTICIPACIONES
# 12                        CUOTAS DE FONDOS COLECTIVOS
# 13      VALORES DE  TITULARIZACIÃN DE PARTICIPACIÃN
# 14                         UNIDADES DE PARTICIPACIÃN
# 15                         INVERSIONES EN EL EXTERIOR
# 16                                              OTROS
# 17                                         RENTA FIJA
# 18                                             AVALES
# 19                                   BONOS DEL ESTADO
# 20                                    BONOS DE PRENDA
# 21                              CÃDULAS HIPOTECARIAS
# 22                           CERTIFICADOS FINANCIEROS
# 23                         CERTIFICADOS DE INVERSIÃN
# 24                         CERTIFICADOS DE TESORERÃA
# 25                          CERTIFICADOS DE DEPÃSITO
# 26                                            CUPONES
# 27                                 DEPÃSITOS A PLAZO
# 28                                   LETRAS DE CAMBIO
# 29                                  NOTAS DE CRÃDITO
# 30                                       OBLIGACIONES
# 31                   FACTURAS COMERCIALES NEGOCIABLES
# 32                                         OVERNIGHTS
# 33              OBLIGACIONES CONVERTIBLES EN ACCIONES
# 34                                    PAPEL COMERCIAL
# 35                                           PAGARÃS
# 36                           PÃLIZAS DE ACUMULACIÃN
# 37                         TÃTULOS DEL BANCO CENTRAL
# 38                         VALORES DE TITULARIZACIÃN
# 39                         INVERSIONES EN EL EXTERIOR
# 40                                              OTROS
# 41                                          DERIVADOS
# 42                                            FORWARD
# 43                                            FUTUROS
# 44                                           OPCIONES
# 45                                              OTROS
# 46  ACTIVOS FINANCIEROS A VALOR RAZONABLE CON CAMB...
# 47                                     RENTA VARIABLE
# 48                         ACCIONES Y PARTICIPACIONES
# 49                                        10102020102
#
#      Jun 24, 20       Unnamed: 3
# 0           NaN              NaN
# 1       CÃDIGO  VALOR (En USD$)
# 2             1    2121860458.59
# 3           101     712903728.96
# 4         10101      19959678.50
# 5       1010101        345391.69
# 6       1010102             0.00
# 7       1010103      19614286.81
# 8         10102     439367682.04
# 9       1010201     304394782.36
# 10    101020101             0.00
# 11  10102010101             0.00
# 12  10102010102             0.00
# 13  10102010103             0.00
# 14  10102010104             0.00
# 15  10102010105             0.00
# 16  10102010106             0.00
# 17    101020102     304394782.36
# 18  10102010201             0.00
# 19  10102010202             0.00
# 20  10102010203             0.00
# 21  10102010204             0.00
# 22  10102010205             0.00
# 23  10102010206     275000000.00
# 24  10102010207             0.00
# 25  10102010208             0.00
# 26  10102010209             0.00
# 27  10102010210             0.00
# 28  10102010211             0.00
# 29  10102010212             0.00
# 30  10102010213             0.00
# 31  10102010214             0.00
# 32  10102010215             0.00
# 33  10102010216             0.00
# 34  10102010217             0.00
# 35  10102010218             0.00
# 36  10102010219             0.00
# 37  10102010220             0.00
# 38  10102010221             0.00
# 39  10102010222      20002383.71
# 40  10102010223       9392398.65
# 41    101020103             0.00
# 42  10102010301             0.00
# 43  10102010302             0.00
# 44  10102010303             0.00
# 45  10102010304             0.00
# 46      1010202             0.00
# 47    101020201             0.00
# 48  10102020101             0.00
# 49         0.00              NaN

# %%
print(daf1.index[49]) # o con -1
daf1.fillna("d", inplace=True)
daf1.rename(inplace=True, columns={"null": "CODS"})

daf1.drop(["Unnamed: 0"], axis=1, inplace=True)
daf1.iloc[daf1.index[-1]] = {"FECHA DE LA JUNTA QUE APROBÓ LOS ESTADOS FINANCIEROS (DD/MM/AAA)":"CUOTAS DE FONDOS COLECTIVOS",
                            "CODS":"10102020102", "Unnamed: 3":"0.00"}

daf1.rename(inplace=True, columns={"FECHA DE LA JUNTA QUE APROBÓ LOS ESTADOS FINANCIEROS (DD/MM/AAA)":"CUENTA", 
                                "CODS":"CODS1",  "Unnamed: 3":"VALOR EN USD"})
daf1.drop("CODS1", axis=1, inplace=True)
daf1.drop([0,1], inplace=True)
daf1.head(10)
# Out:
# 49
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_53945/3088571183.py in <module>
#       9 daf1.rename(inplace=True, columns={"FECHA DE LA JUNTA QUE APROBÓ LOS ESTADOS FINANCIEROS (DD/MM/AAA)":"CUENTA",
#      10                                 "CODS":"CODS1",  "Unnamed: 3":"VALOR EN USD"})
# ---> 11 daf1.drop("CODS1", axis=1, inplace=True)
#      12 daf1.drop([0,1], inplace=True)
#      13 daf1.head(10)
#
# ~/.local/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/.local/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~/.local/lib/python3.9/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~/.local/lib/python3.9/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~/.local/lib/python3.9/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['CODS1'] not found in axis"

# %%
daf1
# Out:
#    FECHA DE LA JUNTA QUE APROBÃ LOS ESTADOS FINANCIEROS (DD/MM/AAA)  \
# 0                     ESTADO DE SITUACIÃN FINANCIERA
# 1                                              CUENTA
# 2                                              ACTIVO
# 3                                    ACTIVO CORRIENTE
# 4                 EFECTIVO Y EQUIVALENTES DE EFECTIVO
# 5                                                CAJA
# 6                 INSTITUCIONES FINANCIERAS PÃBLICAS
# 7                  INSTITUCIONES FINANCIERAS PRIVADAS
# 8                                 ACTIVOS FINANCIEROS
# 9   ACTIVOS FINANCIEROS A VALOR RAZONABLE CON CAMB...
# 10                                     RENTA VARIABLE
# 11                         ACCIONES Y PARTICIPACIONES
# 12                        CUOTAS DE FONDOS COLECTIVOS
# 13      VALORES DE  TITULARIZACIÃN DE PARTICIPACIÃN
# 14                         UNIDADES DE PARTICIPACIÃN
# 15                         INVERSIONES EN EL EXTERIOR
# 16                                              OTROS
# 17                                         RENTA FIJA
# 18                                             AVALES
# 19                                   BONOS DEL ESTADO
# 20                                    BONOS DE PRENDA
# 21                              CÃDULAS HIPOTECARIAS
# 22                           CERTIFICADOS FINANCIEROS
# 23                         CERTIFICADOS DE INVERSIÃN
# 24                         CERTIFICADOS DE TESORERÃA
# 25                          CERTIFICADOS DE DEPÃSITO
# 26                                            CUPONES
# 27                                 DEPÃSITOS A PLAZO
# 28                                   LETRAS DE CAMBIO
# 29                                  NOTAS DE CRÃDITO
# 30                                       OBLIGACIONES
# 31                   FACTURAS COMERCIALES NEGOCIABLES
# 32                                         OVERNIGHTS
# 33              OBLIGACIONES CONVERTIBLES EN ACCIONES
# 34                                    PAPEL COMERCIAL
# 35                                           PAGARÃS
# 36                           PÃLIZAS DE ACUMULACIÃN
# 37                         TÃTULOS DEL BANCO CENTRAL
# 38                         VALORES DE TITULARIZACIÃN
# 39                         INVERSIONES EN EL EXTERIOR
# 40                                              OTROS
# 41                                          DERIVADOS
# 42                                            FORWARD
# 43                                            FUTUROS
# 44                                           OPCIONES
# 45                                              OTROS
# 46  ACTIVOS FINANCIEROS A VALOR RAZONABLE CON CAMB...
# 47                                     RENTA VARIABLE
# 48                         ACCIONES Y PARTICIPACIONES
# 49                                                NaN
#
#      Jun 24, 20     VALOR EN USD
# 0             d                d
# 1       CÃDIGO  VALOR (En USD$)
# 2             1    2121860458.59
# 3           101     712903728.96
# 4         10101      19959678.50
# 5       1010101        345391.69
# 6       1010102             0.00
# 7       1010103      19614286.81
# 8         10102     439367682.04
# 9       1010201     304394782.36
# 10    101020101             0.00
# 11  10102010101             0.00
# 12  10102010102             0.00
# 13  10102010103             0.00
# 14  10102010104             0.00
# 15  10102010105             0.00
# 16  10102010106             0.00
# 17    101020102     304394782.36
# 18  10102010201             0.00
# 19  10102010202             0.00
# 20  10102010203             0.00
# 21  10102010204             0.00
# 22  10102010205             0.00
# 23  10102010206     275000000.00
# 24  10102010207             0.00
# 25  10102010208             0.00
# 26  10102010209             0.00
# 27  10102010210             0.00
# 28  10102010211             0.00
# 29  10102010212             0.00
# 30  10102010213             0.00
# 31  10102010214             0.00
# 32  10102010215             0.00
# 33  10102010216             0.00
# 34  10102010217             0.00
# 35  10102010218             0.00
# 36  10102010219             0.00
# 37  10102010220             0.00
# 38  10102010221             0.00
# 39  10102010222      20002383.71
# 40  10102010223       9392398.65
# 41    101020103             0.00
# 42  10102010301             0.00
# 43  10102010302             0.00
# 44  10102010303             0.00
# 45  10102010304             0.00
# 46      1010202             0.00
# 47    101020201             0.00
# 48  10102020101             0.00
# 49          NaN             0.00

# %%
daf2
# Out:
#     Unnamed: 0                    ESTADO DE SITUACIÃN FINANCIERA  \
# 0          NaN                                             CUENTA
# 1          NaN                         UNIDADES DE PARTICIPACIÃN
# 2          NaN      VALORES DE  TITULARIZACIÃN DE PARTICIPACIÃN
# 3          NaN                         INVERSIONES EN EL EXTERIOR
# 4          NaN                                              OTROS
# 5          NaN                                         RENTA FIJA
# 6          NaN                                             AVALES
# 7          NaN                                   BONOS DEL ESTADO
# 8          NaN                                    BONOS DE PRENDA
# 9          NaN                              CÃDULAS HIPOTECARIAS
# 10         NaN                           CERTIFICADOS FINANCIEROS
# 11         NaN                         CERTIFICADOS DE INVERSIÃN
# 12         NaN                         CERTIFICADOS DE TESORERÃA
# 13         NaN                          CERTIFICADOS DE DEPÃSITO
# 14         NaN                                            CUPONES
# 15         NaN                                 DEPÃSITOS A PLAZO
# 16         NaN                                   LETRAS DE CAMBIO
# 17         NaN                                  NOTAS DE CRÃDITO
# 18         NaN                                       OBLIGACIONES
# 19         NaN                   FACTURAS COMERCIALES NEGOCIABLES
# 20         NaN                                         OVERNIGHTS
# 21         NaN              OBLIGACIONES CONVERTIBLES EN ACCIONES
# 22         NaN                                    PAPEL COMERCIAL
# 23         NaN                                           PAGARÃS
# 24         NaN                           PÃLIZAS DE ACUMULACIÃN
# 25         NaN                         TÃTULOS DEL BANCO CENTRAL
# 26         NaN                         VALORES DE TITULARIZACIÃN
# 27         NaN                         INVERSIONES EN EL EXTERIOR
# 28         NaN                                              OTROS
# 29         NaN            ACTIVOS FINANCIEROS AL COSTO AMORTIZADO
# 30         NaN                                         RENTA FIJA
# 31         NaN                                             AVALES
# 32         NaN                                   BONOS DEL ESTADO
# 33         NaN                                    BONOS DE PRENDA
# 34         NaN                              CÃDULAS HIPOTECARIAS
# 35         NaN                           CERTIFICADOS FINANCIEROS
# 36         NaN                         CERTIFICADOS DE INVERSIÃN
# 37         NaN                         CERTIFICADOS DE TESORERÃA
# 38         NaN                          CERTIFICADOS DE DEPÃSITO
# 39         NaN                                            CUPONES
# 40         NaN                                 DEPÃSITOS A PLAZO
# 41         NaN                                   LETRAS DE CAMBIO
# 42         NaN                                  NOTAS DE CRÃDITO
# 43         NaN                                       OBLIGACIONES
# 44         NaN                   FACTURAS COMERCIALES NEGOCIABLES
# 45         NaN                                         OVERNIGHTS
# 46         NaN              OBLIGACIONES CONVERTIBLES EN ACCIONES
# 47         NaN                                    PAPEL COMERCIAL
# 48         NaN                                           PAGARÃS
# 49         NaN                           PÃLIZAS DE ACUMULACIÃN
# 50         NaN                         TÃTULOS DEL BANCO CENTRAL
# 51         NaN                         VALORES DE TITULARIZACIÃN
# 52         NaN                         INVERSIONES EN EL EXTERIOR
# 53         NaN                                              OTROS
# 54         NaN    PROVISIÃN POR DETERIORO DE ACTIVOS FINANCIEROS
# 55         NaN  ACTIVOS FINANCIEROS A VALOR RAZONABLE CON CAMB...
#
#      Unnamed: 2       Unnamed: 3
# 0       CÃDIGO  VALOR (En USD$)
# 1   10102020103             0.00
# 2   10102020104             0.00
# 3   10102020105             0.00
# 4   10102020106             0.00
# 5     101020202             0.00
# 6   10102020201             0.00
# 7   10102020202             0.00
# 8   10102020203             0.00
# 9   10102020204             0.00
# 10  10102020205             0.00
# 11  10102020206             0.00
# 12  10102020207             0.00
# 13  10102020208             0.00
# 14  10102020209             0.00
# 15  10102020210             0.00
# 16  10102020211             0.00
# 17  10102020212             0.00
# 18  10102020213             0.00
# 19  10102020214             0.00
# 20  10102020215             0.00
# 21  10102020216             0.00
# 22  10102020217             0.00
# 23  10102020218             0.00
# 24  10102020219             0.00
# 25  10102020220             0.00
# 26  10102020221             0.00
# 27  10102020222             0.00
# 28  10102020223             0.00
# 29      1010203             0.00
# 30    101020302             0.00
# 31  10102030201             0.00
# 32  10102030202             0.00
# 33  10102030203             0.00
# 34  10102030204             0.00
# 35  10102030205             0.00
# 36  10102030206             0.00
# 37  10102030207             0.00
# 38  10102030208             0.00
# 39  10102030209             0.00
# 40  10102030210             0.00
# 41  10102030211             0.00
# 42  10102030212             0.00
# 43  10102030213             0.00
# 44  10102030214             0.00
# 45  10102030215             0.00
# 46  10102030216             0.00
# 47  10102030217             0.00
# 48  10102030218             0.00
# 49  10102030219             0.00
# 50  10102030220             0.00
# 51  10102030221             0.00
# 52  10102030222             0.00
# 53  10102030223             0.00
# 54      1010204             0.00
# 55    101020401             0.00

# %%
daf2.drop(["Unnamed: 0","Unnamed: 2"], axis=1, inplace=True)
daf2.drop([0], inplace=True)
daf2.rename(inplace=True, columns={"ESTADO DE SITUACIÓN FINANCIERA":"CUENTA",  "Unnamed: 3":"VALOR EN USD"})
daf2.head(10)
# Out:
#                   ESTADO DE SITUACIÃN FINANCIERA VALOR EN USD
# 1                      UNIDADES DE PARTICIPACIÃN         0.00
# 2   VALORES DE  TITULARIZACIÃN DE PARTICIPACIÃN         0.00
# 3                      INVERSIONES EN EL EXTERIOR         0.00
# 4                                           OTROS         0.00
# 5                                      RENTA FIJA         0.00
# 6                                          AVALES         0.00
# 7                                BONOS DEL ESTADO         0.00
# 8                                 BONOS DE PRENDA         0.00
# 9                           CÃDULAS HIPOTECARIAS         0.00
# 10                       CERTIFICADOS FINANCIEROS         0.00

# %%
daf3
# Out:
#     Unnamed: 0                    ESTADO DE SITUACIÃN FINANCIERA  \
# 0          NaN                                             CUENTA
# 1          NaN            ACTIVOS FINANCIEROS AL COSTO AMORTIZADO
# 2          NaN  ACTIVOS FINANCIEROS A VALOR RAZONABLE CON CAMB...
# 3          NaN  DEUDORES COMERCIALES Y OTRAS CUENTAS POR COBRA...
# 4          NaN    DE ACTIVIDADES ORDINARIAS QUE GENEREN INTERESES
# 5          NaN          CUENTAS Y DOCUMENTOS A COBRAR  A CLIENTES
# 6          NaN          CUENTAS Y DOCUMENTOS A COBRAR  A TERCEROS
# 7          NaN  DE ACTIVIDADES ORDINARIAS QUE NO GENEREN INTER...
# 8          NaN          CUENTAS Y DOCUMENTOS A COBRAR  A CLIENTES
# 9          NaN          CUENTAS Y DOCUMENTOS A COBRAR  A TERCEROS
# 10         NaN                   CUENTAS POR COBRAR AL ORIGINADOR
# 11         NaN            COMISIONES POR OPERACIONES  BURSÃTILES
# 12         NaN                           CONTRATO DE UNDERWRITING
# 13         NaN  POR  ADMINISTRACIÃN Y MANEJO DE PORTAFOLIOS D...
# 14         NaN  POR ADMINISTRACIÃN Y MANEJO DE FONDOS ADMINIS...
# 15         NaN  POR ADMINISTRACIÃN Y MANEJO DE NEGOCIOS FIDUC...
# 16         NaN  POR CUSTODIA Y CONSERVACIÃN DE VALORES MATERI...
# 17         NaN  POR CUSTODIA Y CONSERVACIÃN DE VALORES DESMAT...
# 18         NaN      POR MANEJO DE LIBRO DE ACCIONES Y ACCIONISTAS
# 19         NaN                                      POR ASESORÃA
# 20         NaN                              DIVIDENDOS POR COBRAR
# 21         NaN                               INTERESES POR COBRAR
# 22         NaN            DEUDORES POR INTERMEDIACIÃN DE VALORES
# 23         NaN                              ANTICIPO A COMITENTES
# 24         NaN          ANTICIPO A CONSTRUCTOR POR AVANCE DE OBRA
# 25         NaN                DERECHOS POR COMPROMISO DE RECOMPRA
# 26         NaN           OTRAS CUENTAS POR COBRAR NO RELACIONADAS
# 27         NaN       DOCUMENTOS Y CUENTAS POR COBRAR RELACIONADOS
# 28         NaN                           POR COBRAR A ACCIONISTAS
# 29         NaN              POR COBRAR A COMPAÃÃAS RELACIONADAS
# 30         NaN                              POR COBRAR A CLIENTES
# 31         NaN              OTRAS CUENTAS POR COBRAR RELACIONADAS
# 32         NaN     PROVISIÃN POR CUENTAS INCOBRABLES Y DETERIORO
# 33         NaN                                        INVENTARIOS
# 34         NaN                       INVENTARIOS DE MATERIA PRIMA
# 35         NaN                INVENTARIOS DE PRODUCTOS EN PROCESO
# 36         NaN  INVENTARIOS DE SUMINISTROS O MATERIALES A SER ...
# 37         NaN  INVENTARIOS DE SUMINISTROS O MATERIALES A SER ...
# 38         NaN  INVENTARIOS DE PROD. TERM. Y MERCAD. EN ALMACÃ...
# 39         NaN  INVENTARIOS DE PROD. TERM. Y MERCAD. EN ALMACÃ...
# 40         NaN                          MERCADERÃAS EN TRÃNSITO
# 41         NaN                              OBRAS EN CONSTRUCCION
# 42         NaN                                   OBRAS TERMINADAS
# 43         NaN           MATERIALES O BIENES PARA LA CONSTRUCCION
# 44         NaN   INVENTARIOS REPUESTOS, HERRAMIENTAS Y ACCESORIOS
# 45         NaN                                  OTROS INVENTARIOS
# 46         NaN  (-) PROVISIÃN POR VALOR NETO DE REALIZACIÃN ...
# 47         NaN                SERVICIOS Y OTROS PAGOS ANTICIPADOS
# 48         NaN                     SEGUROS PAGADOS POR ANTICIPADO
# 49         NaN                   ARRIENDOS PAGADOS POR ANTICIPADO
# 50         NaN                            ANTICIPOS A PROVEEDORES
# 51         NaN                         OTROS ANTICIPOS ENTREGADOS
# 52         NaN                   ACTIVOS POR IMPUESTOS CORRIENTES
# 53         NaN    CRÃDITO TRIBUTARIO A FAVOR DE LA EMPRESA (IVA)
# 54         NaN  CRÃDITO TRIBUTARIO A FAVOR DE LA EMPRESA ( I....
# 55         NaN                    ANTICIPO DE IMPUESTO A LA RENTA
#
#      Unnamed: 2       Unnamed: 3
# 0       CÃDIGO  VALOR (En USD$)
# 1     101020402             0.00
# 2     101020403             0.00
# 3       1010205     116721063.13
# 4     101020501      10306441.31
# 5   10102050101      10306441.31
# 6   10102050102             0.00
# 7     101020502     106414621.82
# 8   10102050201     106414621.82
# 9   10102050202             0.00
# 10  10102050203             0.00
# 11  10102050204             0.00
# 12  10102050207             0.00
# 13  10102050208             0.00
# 14  10102050209             0.00
# 15  10102050210             0.00
# 16  10102050211             0.00
# 17  10102050212             0.00
# 18  10102050213             0.00
# 19  10102050214             0.00
# 20  10102050215             0.00
# 21  10102050216             0.00
# 22  10102050217             0.00
# 23  10102050218             0.00
# 24  10102050219             0.00
# 25  10102050220             0.00
# 26  10102050221             0.00
# 27      1010206      19551851.55
# 28    101020601             0.00
# 29    101020602       7888037.19
# 30    101020603       2282783.25
# 31    101020604       9381031.11
# 32      1010207      -1300015.00
# 33        10103     246037667.55
# 34      1010301             0.00
# 35      1010302             0.00
# 36      1010303             0.00
# 37      1010304       3594266.34
# 38      1010305             0.00
# 39      1010306     237438893.62
# 40      1010307       5004507.59
# 41      1010308             0.00
# 42      1010309             0.00
# 43      1010310             0.00
# 44      1010311             0.00
# 45      1010312             0.00
# 46      1010313             0.00
# 47        10104       7456851.46
# 48      1010401        391666.61
# 49      1010402        551624.89
# 50      1010403       6091178.98
# 51      1010404        422380.98
# 52        10105             0.00
# 53      1010501             0.00
# 54      1010502             0.00
# 55      1010503             0.00

# %%
daf3.drop(["Unnamed: 0", "Unnamed: 2"], axis=1, inplace=True)
daf3.drop([0], inplace=True)
daf3.rename(inplace=True, columns={"ESTADO DE SITUACIÓN FINANCIERA":"CUENTA",  "Unnamed: 3":"VALOR EN USD"})
daf3.head(10)
# Out:
#                       ESTADO DE SITUACIÃN FINANCIERA  VALOR EN USD
# 1             ACTIVOS FINANCIEROS AL COSTO AMORTIZADO          0.00
# 2   ACTIVOS FINANCIEROS A VALOR RAZONABLE CON CAMB...          0.00
# 3   DEUDORES COMERCIALES Y OTRAS CUENTAS POR COBRA...  116721063.13
# 4     DE ACTIVIDADES ORDINARIAS QUE GENEREN INTERESES   10306441.31
# 5           CUENTAS Y DOCUMENTOS A COBRAR  A CLIENTES   10306441.31
# 6           CUENTAS Y DOCUMENTOS A COBRAR  A TERCEROS          0.00
# 7   DE ACTIVIDADES ORDINARIAS QUE NO GENEREN INTER...  106414621.82
# 8           CUENTAS Y DOCUMENTOS A COBRAR  A CLIENTES  106414621.82
# 9           CUENTAS Y DOCUMENTOS A COBRAR  A TERCEROS          0.00
# 10                   CUENTAS POR COBRAR AL ORIGINADOR          0.00

# %%
daf4
# Out:
#     Unnamed: 0                    ESTADO DE SITUACIÃN FINANCIERA Unnamed: 2  \
# 0          NaN                                             CUENTA    CÃDIGO
# 1          NaN  ACTIVOS CORRIENTES MANTENIDOS PARA LA VENTA Y ...      10106
# 2          NaN  CONSTRUCCIONES EN PROCESO (NIC 11 Y SECC.23 PY...      10107
# 3          NaN                           OTROS ACTIVOS CORRIENTES      10108
# 4          NaN                              ACTIVOS NO CORRIENTES        102
# 5          NaN                         PROPIEDAD, PLANTA Y EQUIPO      10201
# 6          NaN                                           TERRENOS    1020101
# 7          NaN                                          EDIFICIOS    1020102
# 8          NaN                            CONSTRUCCIONES EN CURSO    1020103
# 9          NaN                                      INSTALACIONES    1020104
# 10         NaN                                  MUEBLES Y ENSERES    1020105
# 11         NaN                                MAQUINARIA Y EQUIPO    1020106
# 12         NaN            NAVES, AEREONAVES, BARCAZAS Y SIMILARES    1020107
# 13         NaN                             EQUIPO DE COMPUTACIÃN    1020108
# 14         NaN  VEHÃCULOS, EQUIPOS DE TRASPORTE Y EQUIPO CAMI...    1020109
# 15         NaN                 OTROS PROPIEDADES, PLANTA Y EQUIPO    1020110
# 16         NaN                           REPUESTOS Y HERRAMIENTAS    1020111
# 17         NaN  (-) DEPRECIACIÃN ACUMULADA PROPIEDADES, PLANT...    1020112
# 18         NaN  (-) DETERIORO  ACUMULADO DE PROPIEDADES, PLANT...    1020113
# 19         NaN               ACTIVOS DE EXPLORACION Y EXPLOTACION    1020114
# 20         NaN               ACTIVOS DE EXPLORACION Y EXPLOTACION  102011401
# 21         NaN  (-) AMORTIZACION ACUMULADA DE ACTIVOS DE EXPLO...  102011402
# 22         NaN  (-) DETERIORO  ACUMULADO DE ACTIVOS DE EXPLORA...  102011403
# 23         NaN                          PROPIEDADES DE INVERSIÃN      10202
# 24         NaN                                           TERRENOS    1020201
# 25         NaN                                           TERRENOS  102020101
# 26         NaN       DERECHOS DE USO SOBRE TERRENOS SUBARRENDADOS  102020102
# 27         NaN                                          EDIFICIOS    1020202
# 28         NaN                                          EDIFICIOS  102020201
# 29         NaN      DERECHOS DE USO SOBRE EDIFICIOS SUBARRENDADOS  102020202
# 30         NaN  (-) DEPRECIACION ACUMULADA DE PROPIEDADES DE I...    1020203
# 31         NaN  (-) DETERIORO ACUMULADO DE PROPIEDADES DE INVE...    1020204
# 32         NaN                                 ACTIVOS BIOLOGICOS      10203
# 33         NaN                      ANIMALES VIVOS EN CRECIMIENTO    1020301
# 34         NaN                       ANIMALES VIVOS EN PRODUCCION    1020302
# 35         NaN                             PLANTAS EN CRECIMIENTO    1020303
# 36         NaN                              PLANTAS EN PRODUCCION    1020304
# 37         NaN  (-) DEPRECIACION ACUMULADA DE ACTIVOS BIOLÃGICOS    1020305
# 38         NaN     (-) DETERIORO ACUMULADO DE ACTIVOS BIOLOGÃCOS    1020306
# 39         NaN                                  ACTIVO INTANGIBLE      10204
# 40         NaN                                        PLUSVALÃAS    1020401
# 41         NaN  MARCAS, PATENTES, DERECHOS DE LLAVE , CUOTAS P...    1020402
# 42         NaN                            CONCESIONES Y LICENCIAS    1020403
# 43         NaN               ACTIVOS DE EXPLORACION Y EXPLOTACION    1020404
# 44         NaN  (-) AMORTIZACIÃN ACUMULADA DE ACTIVOS INTANGIBLE    1020405
# 45         NaN       (-) DETERIORO ACUMULADO DE ACTIVO INTANGIBLE    1020406
# 46         NaN                                  OTROS INTANGIBLES    1020407
# 47         NaN                    ACTIVOS POR IMPUESTOS DIFERIDOS      10205
# 48         NaN                  ACTIVOS FINANCIEROS NO CORRIENTES      10206
# 49         NaN  ACTIVOS FINANCIEROS A VALOR RAZONABLE CON CAMB...    1020601
# 50         NaN  (-) PROVISION POR DETERIORO DE ACTIVOS FINANCI...    1020602
# 51         NaN             ACTIVOS FINANCIEROS A COSTO AMORTIZADO    1020603
# 52         NaN  (-) PROVISIÃN POR DETERIORO DE ACTIVOS FINANC...    1020604
# 53         NaN  ACTIVOS FINANCIEROS A VALOR RAZONABLE CON CAMB...    1020605
# 54         NaN  (-)PROVISIÃN POR DETERIORO DE ACTIVOS FINANCI...    1020606
# 55         NaN              DERECHO DE USO POR ACTIVOS ARRENDADOS      10207
#
#          Unnamed: 3
# 0   VALOR (En USD$)
# 1              0.00
# 2              0.00
# 3          81849.41
# 4     1408956729.63
# 5      737751589.78
# 6      182709291.22
# 7      334761668.20
# 8       10243362.50
# 9      235932018.04
# 10      22289412.76
# 11     243830801.68
# 12             0.00
# 13      52449228.02
# 14      17119751.18
# 15      29292068.64
# 16             0.00
# 17    -390876012.46
# 18             0.00
# 19             0.00
# 20             0.00
# 21             0.00
# 22             0.00
# 23      89355271.35
# 24             0.00
# 25             0.00
# 26             0.00
# 27     118385571.16
# 28     118385571.16
# 29             0.00
# 30     -29030299.81
# 31             0.00
# 32             0.00
# 33             0.00
# 34             0.00
# 35             0.00
# 36             0.00
# 37             0.00
# 38             0.00
# 39      40475597.35
# 40             0.00
# 41             0.00
# 42             0.00
# 43             0.00
# 44     -25441463.48
# 45             0.00
# 46      65917060.83
# 47       3176668.88
# 48             0.00
# 49             0.00
# 50             0.00
# 51             0.00
# 52             0.00
# 53             0.00
# 54             0.00
# 55      91931517.88

# %%
daf4.drop(["Unnamed: 0", "Unnamed: 2"], axis=1, inplace=True)
daf4.drop([0], inplace=True)
daf4.rename(inplace=True, columns={"ESTADO DE SITUACIÓN FINANCIERA":"CUENTA",  "Unnamed: 3":"VALOR EN USD"})
daf4.head(10)
# Out:
#                       ESTADO DE SITUACIÃN FINANCIERA   VALOR EN USD
# 1   ACTIVOS CORRIENTES MANTENIDOS PARA LA VENTA Y ...           0.00
# 2   CONSTRUCCIONES EN PROCESO (NIC 11 Y SECC.23 PY...           0.00
# 3                            OTROS ACTIVOS CORRIENTES       81849.41
# 4                               ACTIVOS NO CORRIENTES  1408956729.63
# 5                          PROPIEDAD, PLANTA Y EQUIPO   737751589.78
# 6                                            TERRENOS   182709291.22
# 7                                           EDIFICIOS   334761668.20
# 8                             CONSTRUCCIONES EN CURSO    10243362.50
# 9                                       INSTALACIONES   235932018.04
# 10                                  MUEBLES Y ENSERES    22289412.76

# %%
daf5
# Out:
#     Unnamed: 0                    ESTADO DE SITUACIÃN FINANCIERA Unnamed: 2  \
# 0          NaN                                             CUENTA    CÃDIGO
# 1          NaN  (-) DEPRECIACIÃN ACUMULADA DE ACTIVOS PROVENI...    1020701
# 2          NaN  (-) DETERIORO ACUMULADO DE ACTIVOS PROVENIENTE...    1020702
# 3          NaN              DERECHO DE USO POR ACTIVOS ARRENDADOS    1020703
# 4          NaN                        OTROS ACTIVOS NO CORRIENTES      10208
# 5          NaN                               DERECHOS FIDUCIARIOS    1020801
# 6          NaN                            DEPÃSITOS EN GARANTÃA    1020802
# 7          NaN  DEPÃSITOS EN GARANTÃA POR OPERACIONES BURSÃ...    1020803
# 8          NaN     ACCIONES DEL DEPÃSITO CENTRALIZADO DE VALORES    1020805
# 9          NaN                           INVERSIONES SUBSIDIARIAS    1020806
# 10         NaN                              INVERSIONES ASOCIADAS    1020807
# 11         NaN                     INVERSIONES NEGOCIOS CONJUNTOS    1020808
# 12         NaN                                  OTRAS INVERSIONES    1020809
# 13         NaN           (-) PROVISIÃN VALUACIÃN DE INVERSIONES    1020810
# 14         NaN                        OTROS ACTIVOS NO CORRIENTES    1020811
# 15         NaN    DOCUMENTOS Y CUENTAS POR COBRAR NO RELACIONADOS      10209
# 16         NaN          CUENTAS Y DOCUMENTOS A COBRAR  A CLIENTES    1020901
# 17         NaN          CUENTAS Y DOCUMENTOS A COBRAR  A TERCEROS    1020902
# 18         NaN           OTRAS CUENTAS POR COBRAR NO RELACIONADAS    1020903
# 19         NaN       DOCUMENTOS Y CUENTAS POR COBRAR RELACIONADOS      10210
# 20         NaN                           POR COBRAR A ACCIONISTAS    1021001
# 21         NaN              POR COBRAR A COMPAÃÃAS RELACIONADAS    1021002
# 22         NaN                              POR COBRAR A CLIENTES    1021003
# 23         NaN              OTRAS CUENTAS POR COBRAR RELACIONADAS    1021004
# 24         NaN                                             PASIVO          2
# 25         NaN                                   PASIVO CORRIENTE        201
# 26         NaN  PASIVOS FINANCIEROS A VALOR RAZONABLE CON CAMB...      20101
# 27         NaN             PASIVOS POR CONTRATOS DE ARRENDAMIENTO      20102
# 28         NaN                     CUENTAS Y DOCUMENTOS POR PAGAR      20103
# 29         NaN                                            LOCALES    2010301
# 30         NaN                                         PRÃSTAMOS  201030101
# 31         NaN                                        PROVEEDORES  201030102
# 32         NaN                                              OTRAS  201030103
# 33         NaN                                       DEL EXTERIOR    2010302
# 34         NaN                                         PRÃSTAMOS  201030201
# 35         NaN                                        PROVEEDORES  201030202
# 36         NaN                                              OTRAS  201030203
# 37         NaN         OBLIGACIONES CON INSTITUCIONES FINANCIERAS      20104
# 38         NaN                                            LOCALES    2010401
# 39         NaN                                       DEL EXTERIOR    2010402
# 40         NaN                                        PROVISIONES      20105
# 41         NaN                                            LOCALES    2010501
# 42         NaN                                       DEL EXTERIOR    2010502
# 43         NaN             PORCIÃN CORRIENTE DE VALORES EMITIDOS      20106
# 44         NaN                                       OBLIGACIONES    2010601
# 45         NaN                                    PAPEL COMERCIAL    2010602
# 46         NaN                         VALORES DE TITULARIZACIÃN    2010603
# 47         NaN                                              OTROS    2010604
# 48         NaN                                INTERESES POR PAGAR    2010605
# 49         NaN                      OTRAS OBLIGACIONES CORRIENTES      20107
# 50         NaN                  CON LA ADMINISTRACIÃN TRIBUTARIA    2010701
# 51         NaN        IMPUESTO A LA RENTA POR PAGAR DEL EJERCICIO    2010702
# 52         NaN                                        CON EL IESS    2010703
# 53         NaN                  POR BENEFICIOS DE LEY A EMPLEADOS    2010704
# 54         NaN  PARTICIPACIÃN TRABAJADORES POR PAGAR DEL EJER...    2010705
# 55         NaN                               DIVIDENDOS POR PAGAR    2010706
#
#          Unnamed: 3
# 0   VALOR (En USD$)
# 1      -30709905.78
# 2              0.00
# 3      122641423.66
# 4      446266084.39
# 5              0.00
# 6              0.00
# 7              0.00
# 8              0.00
# 9      432054868.95
# 10      11319000.00
# 11             0.00
# 12             0.00
# 13             0.00
# 14       2892215.44
# 15             0.00
# 16             0.00
# 17             0.00
# 18             0.00
# 19             0.00
# 20             0.00
# 21             0.00
# 22             0.00
# 23             0.00
# 24     638887322.93
# 25     317787592.69
# 26             0.00
# 27       6089738.50
# 28     158828898.34
# 29     154713410.49
# 30             0.00
# 31     154713410.49
# 32             0.00
# 33       4115487.85
# 34             0.00
# 35             0.00
# 36       4115487.85
# 37      25625968.65
# 38             0.00
# 39      25625968.65
# 40             0.00
# 41             0.00
# 42             0.00
# 43             0.00
# 44             0.00
# 45             0.00
# 46             0.00
# 47             0.00
# 48             0.00
# 49      96859125.76
# 50      10654252.27
# 51       7274543.52
# 52       2821520.51
# 53      17341581.97
# 54      33029718.00
# 55       5240443.31

# %%
daf5.drop(["Unnamed: 0", "Unnamed: 2"], axis=1, inplace=True)
daf5.drop([0], inplace=True)
daf5.rename(inplace=True, columns={"ESTADO DE SITUACIÓN FINANCIERA":"CUENTA",  "Unnamed: 3":"VALOR EN USD"})
daf5.head(10)
# Out:
#                       ESTADO DE SITUACIÃN FINANCIERA  VALOR EN USD
# 1   (-) DEPRECIACIÃN ACUMULADA DE ACTIVOS PROVENI...  -30709905.78
# 2   (-) DETERIORO ACUMULADO DE ACTIVOS PROVENIENTE...          0.00
# 3               DERECHO DE USO POR ACTIVOS ARRENDADOS  122641423.66
# 4                         OTROS ACTIVOS NO CORRIENTES  446266084.39
# 5                                DERECHOS FIDUCIARIOS          0.00
# 6                             DEPÃSITOS EN GARANTÃA          0.00
# 7   DEPÃSITOS EN GARANTÃA POR OPERACIONES BURSÃ...          0.00
# 8      ACCIONES DEL DEPÃSITO CENTRALIZADO DE VALORES          0.00
# 9                            INVERSIONES SUBSIDIARIAS  432054868.95
# 10                              INVERSIONES ASOCIADAS   11319000.00

# %%
daf6
# Out:
#     Unnamed: 0                    ESTADO DE SITUACIÃN FINANCIERA Unnamed: 2  \
# 0          NaN                                             CUENTA    CÃDIGO
# 1          NaN                                              OTROS    2010707
# 2          NaN                   CUENTAS POR PAGAR A RELACIONADAS      20108
# 3          NaN                                            LOCALES    2010801
# 4          NaN                          PRÃSTAMOS DE ACCIONISTAS  201080101
# 5          NaN             PRÃSTAMOS DE COMPAÃÃAS RELACIONADAS  201080102
# 6          NaN                                        PROVEEDORES  201080103
# 7          NaN                                              OTROS  201080104
# 8          NaN                                       DEL EXTERIOR    2010802
# 9          NaN                          PRÃSTAMOS DE ACCIONISTAS  201080201
# 10         NaN             PRÃSTAMOS DE COMPAÃÃAS RELACIONADAS  201080202
# 11         NaN                                        PROVEEDORES  201080203
# 12         NaN                                              OTROS  201080204
# 13         NaN                          OTROS PASIVOS FINANCIEROS      20109
# 14         NaN                                          ANTICIPOS      20110
# 15         NaN                              ANTICIPOS DE CLIENTES    2011001
# 16         NaN                          OTROS ANTICIPOS RECIBIDOS    2011002
# 17         NaN  PASIVOS DIRECTAMENTE ASOCIADOS CON LOS ACTIVOS...      20111
# 18         NaN  PORCION CORRIENTE DE PROVISIONES POR BENEFICIO...      20112
# 19         NaN                                JUBILACION PATRONAL    2011201
# 20         NaN                OTROS BENEFICIOS PARA LOS EMPLEADOS    2011202
# 21         NaN                           OTROS PASIVOS CORRIENTES      20113
# 22         NaN                               COMISIONES POR PAGAR    2011301
# 23         NaN                        POR OPERACIONES BURSÃTILES    2011302
# 24         NaN                                       POR CUSTODIA    2011303
# 25         NaN                                POR ADMINISTRACIÃN    2011304
# 26         NaN                                   OTRAS COMISIONES    2011305
# 27         NaN                                 SANCIONES Y MULTAS    2011306
# 28         NaN                                    INDEMNIZACIONES    2011307
# 29         NaN                            OBLIGACIONES JUDICIALES    2011308
# 30         NaN                     ACREEDORES POR INTERMEDIACIÃN    2011309
# 31         NaN             OBLIGACIÃN POR COMPROMISO DE RECOMPRA    2011310
# 32         NaN                      POR CONTRATOS DE UNDERWRITING    2011311
# 33         NaN                                              OTROS    2011312
# 34         NaN            PASIVOS FINANCIEROS AL COSTO AMORTIZADO      20114
# 35         NaN                                PASIVO NO CORRIENTE        202
# 36         NaN             PASIVOS POR CONTRATOS DE ARRENDAMIENTO      20201
# 37         NaN                     CUENTAS Y DOCUMENTOS POR PAGAR      20202
# 38         NaN                                            LOCALES    2020201
# 39         NaN                                         PRÃSTAMOS  202020101
# 40         NaN                                        PROVEEDORES  202020102
# 41         NaN                                              OTRAS  202020103
# 42         NaN                                       DEL EXTERIOR    2020202
# 43         NaN                                         PRÃSTAMOS  202020201
# 44         NaN                                        PROVEEDORES  202020202
# 45         NaN                                              OTRAS  202020203
# 46         NaN         OBLIGACIONES CON INSTITUCIONES FINANCIERAS      20203
# 47         NaN                                            LOCALES    2020301
# 48         NaN                                       DEL EXTERIOR    2020302
# 49         NaN                   CUENTAS POR PAGAR A RELACIONADAS      20204
# 50         NaN                                            LOCALES    2020401
# 51         NaN                          PRÃSTAMOS DE ACCIONISTAS  202040101
# 52         NaN             PRÃSTAMOS DE COMPAÃÃAS RELACIONADAS  202040102
# 53         NaN                                        PROVEEDORES  202040103
# 54         NaN                                              OTROS  202040104
# 55         NaN                                       DEL EXTERIOR    2020402
#
#          Unnamed: 3
# 0   VALOR (En USD$)
# 1       20497066.18
# 2       13552616.56
# 3       10762634.08
# 4              0.00
# 5              0.00
# 6       10762634.08
# 7              0.00
# 8        2789982.48
# 9              0.00
# 10             0.00
# 11       2789982.48
# 12             0.00
# 13             0.00
# 14             0.00
# 15             0.00
# 16             0.00
# 17             0.00
# 18             0.00
# 19             0.00
# 20             0.00
# 21      16831244.88
# 22             0.00
# 23             0.00
# 24             0.00
# 25             0.00
# 26             0.00
# 27             0.00
# 28             0.00
# 29             0.00
# 30             0.00
# 31             0.00
# 32             0.00
# 33      16831244.88
# 34             0.00
# 35     321099730.24
# 36      38485527.82
# 37             0.00
# 38             0.00
# 39             0.00
# 40             0.00
# 41             0.00
# 42             0.00
# 43             0.00
# 44             0.00
# 45             0.00
# 46     193684210.56
# 47             0.00
# 48     193684210.56
# 49             0.00
# 50             0.00
# 51             0.00
# 52             0.00
# 53             0.00
# 54             0.00
# 55             0.00

# %%
daf6.drop(["Unnamed: 0", "Unnamed: 2"], axis=1, inplace=True)
daf6.drop([0], inplace=True)
daf6.rename(inplace=True, columns={"ESTADO DE SITUACIÓN FINANCIERA":"CUENTA",  "Unnamed: 3":"VALOR EN USD"})
daf6.head(10)
# Out:
#            ESTADO DE SITUACIÃN FINANCIERA VALOR EN USD
# 1                                    OTROS  20497066.18
# 2         CUENTAS POR PAGAR A RELACIONADAS  13552616.56
# 3                                  LOCALES  10762634.08
# 4                PRÃSTAMOS DE ACCIONISTAS         0.00
# 5   PRÃSTAMOS DE COMPAÃÃAS RELACIONADAS         0.00
# 6                              PROVEEDORES  10762634.08
# 7                                    OTROS         0.00
# 8                             DEL EXTERIOR   2789982.48
# 9                PRÃSTAMOS DE ACCIONISTAS         0.00
# 10  PRÃSTAMOS DE COMPAÃÃAS RELACIONADAS         0.00

# %%
daf7
# Out:
#                                            Unnamed: 0  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16  OTROS BENEFICIOS NO CORRIENTES PARA LOS EMPLEADOS
#
#               ESTADO DE SITUACIÃN FINANCIERA Unnamed: 2       Unnamed: 3  \
# 0                                      CUENTA    CÃDIGO  VALOR (En USD$)
# 1                   PRÃSTAMOS DE ACCIONISTAS  202040201             0.00
# 2      PRÃSTAMOS DE COMPAÃÃAS RELACIONADAS  202040202             0.00
# 3                                 PROVEEDORES  202040203             0.00
# 4                                       OTROS  202040204             0.00
# 5   PORCIÃN NO CORRIENTE DE VALORES EMITIDOS      20205             0.00
# 6                                OBLIGACIONES    2020501             0.00
# 7                             PAPEL COMERCIAL    2020502             0.00
# 8                  VALORES DE TITULARIZACIÃN    2020503             0.00
# 9                                       OTROS    2020504             0.00
# 10                        INTERESES POR PAGAR    2020505             0.00
# 11                                  ANTICIPOS      20206             0.00
# 12                      ANTICIPOS DE CLIENTES    2020601             0.00
# 13                  OTROS ANTICIPOS RECIBIDOS    2020602             0.00
# 14     PROVISIONES POR BENEFICIOS A EMPLEADOS      20207      70878748.60
# 15                        JUBILACION PATRONAL    2020701      70030066.60
# 16                                    2020702  848682.00              NaN
#
#     Unnamed: 4
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN

# %%
print(daf7.iloc[-1])
# Out:
# Unnamed: 0                         OTROS BENEFICIOS NO CORRIENTES PARA LOS EMPLEADOS
# ESTADO DE SITUACIÃN FINANCIERA                                              2020702
# Unnamed: 2                                                                 848682.00
# Unnamed: 3                                                                       NaN
# Unnamed: 4                                                                       NaN
# Name: 16, dtype: object

# %%
daf7.drop(["Unnamed: 0","Unnamed: 2","Unnamed: 4"], axis=1, inplace=True)
daf7.drop([0], inplace=True)
daf7.iloc[daf7.index[-1]] = {"ESTADO DE SITUACIÓN FINANCIERA":"PARTICIPACIÓN CONTROLADORA",
                            "Unnamed: 3":"0.00"}
daf7.rename(inplace=True, columns={"ESTADO DE SITUACIÓN FINANCIERA":"CUENTA",  "Unnamed: 3":"VALOR EN USD"})
daf7
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_53945/3047675386.py in <module>
#       1 daf7.drop(["Unnamed: 0","Unnamed: 2","Unnamed: 4"], axis=1, inplace=True)
#       2 daf7.drop([0], inplace=True)
# ----> 3 daf7.iloc[daf7.index[-1]] = {"ESTADO DE SITUACIÓN FINANCIERA":"PARTICIPACIÓN CONTROLADORA",
#       4                             "Unnamed: 3":"0.00"}
#       5 daf7.rename(inplace=True, columns={"ESTADO DE SITUACIÓN FINANCIERA":"CUENTA",  "Unnamed: 3":"VALOR EN USD"})
#
# ~/.local/lib/python3.9/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     718             key = com.apply_if_callable(key, self.obj)
#     719         indexer = self._get_setitem_indexer(key)
# --> 720         self._has_valid_setitem_indexer(key)
#     721
#     722         iloc = self if self.name == "iloc" else self.obj.iloc
#
# ~/.local/lib/python3.9/site-packages/pandas/core/indexing.py in _has_valid_setitem_indexer(self, indexer)
#    1459             elif is_integer(i):
#    1460                 if i >= len(ax):
# -> 1461                     raise IndexError("iloc cannot enlarge its target object")
#    1462             elif isinstance(i, dict):
#    1463                 raise IndexError("iloc cannot enlarge its target object")
#
# IndexError: iloc cannot enlarge its target object

# %%
daf7
# Out:
#               ESTADO DE SITUACIÃN FINANCIERA   Unnamed: 3
# 1                   PRÃSTAMOS DE ACCIONISTAS         0.00
# 2      PRÃSTAMOS DE COMPAÃÃAS RELACIONADAS         0.00
# 3                                 PROVEEDORES         0.00
# 4                                       OTROS         0.00
# 5   PORCIÃN NO CORRIENTE DE VALORES EMITIDOS         0.00
# 6                                OBLIGACIONES         0.00
# 7                             PAPEL COMERCIAL         0.00
# 8                  VALORES DE TITULARIZACIÃN         0.00
# 9                                       OTROS         0.00
# 10                        INTERESES POR PAGAR         0.00
# 11                                  ANTICIPOS         0.00
# 12                      ANTICIPOS DE CLIENTES         0.00
# 13                  OTROS ANTICIPOS RECIBIDOS         0.00
# 14     PROVISIONES POR BENEFICIOS A EMPLEADOS  70878748.60
# 15                        JUBILACION PATRONAL  70030066.60
# 16                                    2020702          NaN

# %%
daf7.drop([16], inplace=True)
#daf7.iloc[daf7.index[15]] = {"CUENTA":"PARTICIPACIÓN CONTROLADORA", "VALOR EN USD":"0.00"}
#daf7

# %%
daf7
# Out:
#               ESTADO DE SITUACIÃN FINANCIERA   Unnamed: 3
# 1                   PRÃSTAMOS DE ACCIONISTAS         0.00
# 2      PRÃSTAMOS DE COMPAÃÃAS RELACIONADAS         0.00
# 3                                 PROVEEDORES         0.00
# 4                                       OTROS         0.00
# 5   PORCIÃN NO CORRIENTE DE VALORES EMITIDOS         0.00
# 6                                OBLIGACIONES         0.00
# 7                             PAPEL COMERCIAL         0.00
# 8                  VALORES DE TITULARIZACIÃN         0.00
# 9                                       OTROS         0.00
# 10                        INTERESES POR PAGAR         0.00
# 11                                  ANTICIPOS         0.00
# 12                      ANTICIPOS DE CLIENTES         0.00
# 13                  OTROS ANTICIPOS RECIBIDOS         0.00
# 14     PROVISIONES POR BENEFICIOS A EMPLEADOS  70878748.60
# 15                        JUBILACION PATRONAL  70030066.60

# %%
nueva_fila = {"CUENTA": "PARTICIPACIÓN CONTROLADORA", "VALOR EN USD": "0.00"}
daf7 = daf7._append(nueva_fila, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_53945/2273899245.py in <module>
#       1 nueva_fila = {"CUENTA": "PARTICIPACIÓN CONTROLADORA", "VALOR EN USD": "0.00"}
# ----> 2 daf7 = daf7._append(nueva_fila, ignore_index=True)
#
# ~/.local/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute '_append'

# %%
daf7
# Out:
#               ESTADO DE SITUACIÃN FINANCIERA   Unnamed: 3
# 1                   PRÃSTAMOS DE ACCIONISTAS         0.00
# 2      PRÃSTAMOS DE COMPAÃÃAS RELACIONADAS         0.00
# 3                                 PROVEEDORES         0.00
# 4                                       OTROS         0.00
# 5   PORCIÃN NO CORRIENTE DE VALORES EMITIDOS         0.00
# 6                                OBLIGACIONES         0.00
# 7                             PAPEL COMERCIAL         0.00
# 8                  VALORES DE TITULARIZACIÃN         0.00
# 9                                       OTROS         0.00
# 10                        INTERESES POR PAGAR         0.00
# 11                                  ANTICIPOS         0.00
# 12                      ANTICIPOS DE CLIENTES         0.00
# 13                  OTROS ANTICIPOS RECIBIDOS         0.00
# 14     PROVISIONES POR BENEFICIOS A EMPLEADOS  70878748.60
# 15                        JUBILACION PATRONAL  70030066.60

# %%
dafHeader
# Out:
#                                           Unnamed: 0  \
# 0                                         DIRECCIÃN
# 1                                         EXPEDIENTE
# 2                                                RUC
# 3                                               AÃO
# 4                                         FORMULARIO
# 5  FECHA DE LA JUNTA QUE APROBÃ LOS ESTADOS FINA...
#
#                                    RAZÃN SOCIAL  CORPORACION FAVORITA C.A.  \
# 0  AV.ELOY ALFARO Y AVIGIRAS No. N52-468 BARRIO:                        NaN
# 1                                            384                        NaN
# 2                                  1790016919001                        NaN
# 3                                           2020                        NaN
# 4                            SCV.NIIF.384.2020.1                        NaN
# 5                                     Jun 24, 20                        NaN
#
#    Unnamed: 3
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN

# %%
dafHeader.drop(["J2R TECH S.A.S.","Unnamed: 3"], axis=1, inplace=True)
dafHeader.rename(inplace=True, columns={"Unnamed: 0":"RAZÓN SOCIAL", "RAZÓN SOCIAL":"J2R TECH S.A.S."})
dafHeader
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_53945/3831865764.py in <module>
# ----> 1 dafHeader.drop(["J2R TECH S.A.S.","Unnamed: 3"], axis=1, inplace=True)
#       2 dafHeader.rename(inplace=True, columns={"Unnamed: 0":"RAZÓN SOCIAL", "RAZÓN SOCIAL":"J2R TECH S.A.S."})
#       3 dafHeader
#
# ~/.local/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/.local/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~/.local/lib/python3.9/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~/.local/lib/python3.9/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~/.local/lib/python3.9/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['J2R TECH S.A.S.'] not found in axis"

# %%
columns_names = ["REPRESENTANTE LEGAL","CONTADOR"]
pandas_options = {"names":columns_names}
contador = tabula.read_pdf(pdf, pages=7, area=(608,16,666,376), lattice=False, output_format="dataframe", encoding="latin-1", multiple_tables=True, pandas_options=pandas_options)
dafContador = contador[0]

# %%
dafContador.drop([0], inplace=True)
dafContador
# Out:
#      REPRESENTANTE LEGAL  CONTADOR
# 1  RESULTADOS ACUMULADOS       NaN
# 2   GANANCIAS ACUMULADAS       NaN

# %%
dafData = pd.concat([daf1,daf2, daf3, daf4, daf5, daf6, daf7])

# %%
dafData
# Out:
#    FECHA DE LA JUNTA QUE APROBÃ LOS ESTADOS FINANCIEROS (DD/MM/AAA)  \
# 0                     ESTADO DE SITUACIÃN FINANCIERA
# 1                                              CUENTA
# 2                                              ACTIVO
# 3                                    ACTIVO CORRIENTE
# 4                 EFECTIVO Y EQUIVALENTES DE EFECTIVO
# ..                                                ...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
#
#    Jun 24, 20     VALOR EN USD         ESTADO DE SITUACIÃN FINANCIERA  \
# 0           d                d                                     NaN
# 1     CÃDIGO  VALOR (En USD$)                                     NaN
# 2           1    2121860458.59                                     NaN
# 3         101     712903728.96                                     NaN
# 4       10101      19959678.50                                     NaN
# ..        ...              ...                                     ...
# 11        NaN              NaN                               ANTICIPOS
# 12        NaN              NaN                   ANTICIPOS DE CLIENTES
# 13        NaN              NaN               OTROS ANTICIPOS RECIBIDOS
# 14        NaN              NaN  PROVISIONES POR BENEFICIOS A EMPLEADOS
# 15        NaN              NaN                     JUBILACION PATRONAL
#
#      Unnamed: 3
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 11         0.00
# 12         0.00
# 13         0.00
# 14  70878748.60
# 15  70030066.60
#
# [340 rows x 5 columns]

# %%
texto = dafData["CUENTA"].to_list()
valores_list = dafData["VALOR EN USD"].to_list()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/.local/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/.local/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CUENTA'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_53945/434927664.py in <module>
# ----> 1 texto = dafData["CUENTA"].to_list()
#       2 valores_list = dafData["VALOR EN USD"].to_list()
#
# ~/.local/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/.local/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'CUENTA'

# %%
valores = np.array(valores_list).reshape(1,-1)
dfDatos = pd.DataFrame(valores, columns=texto)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_53945/1026813105.py in <module>
# ----> 1 valores = np.array(valores_list).reshape(1,-1)
#       2 dfDatos = pd.DataFrame(valores, columns=texto)
#
# NameError: name 'valores_list' is not defined

# %%
dfDatos
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_53945/65544471.py in <module>
# ----> 1 dfDatos
#
# NameError: name 'dfDatos' is not defined

# %%
with pd.ExcelWriter("../Outputs/InfoEconomica.xlsx") as writer:
    dafHeader.to_excel(writer, sheet_name="Encabezado", index=False)
    dafContador.to_excel(writer, sheet_name="Encabezado", index=False, startrow=len(dafHeader)+2)
    dfDatos.to_excel(writer, sheet_name="Datos", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_53945/163722904.py in <module>
#       2     dafHeader.to_excel(writer, sheet_name="Encabezado", index=False)
#       3     dafContador.to_excel(writer, sheet_name="Encabezado", index=False, startrow=len(dafHeader)+2)
# ----> 4     dfDatos.to_excel(writer, sheet_name="Datos", index=False)
#
# NameError: name 'dfDatos' is not defined
